# 15    2018-04-25    1.0
# 16    2018-04-25    1.0
# 17    2018-04-25    1.0
# 18    2018-04-24    1.0
# 19    2018-04-24    1.0
# 20    2018-04-24    1.0
# 21    2018-04-24    1.0
# 22    2018-04-24    1.0
# 23    2018-04-24    1.0
# 24    2018-04-24    1.0
# 25    2018-04-24    1.0
# 26    2018-04-23    0.0
# 27    2018-04-23    0.0
# 28    2018-04-23    0.0
# 29    2018-04-23    0.0
# ...          ...    ...
# 2745  2017-01-20    0.0
# 2746  2017-01-20    0.0
# 2747  2017-01-20    0.0
# 2748  2017-01-19    0.0
# 2749  2017-01-19    0.0
# 2750  2017-01-19    0.0
# 2751  2017-01-19    0.0
# 2752  2017-01-19    0.0
# 2753  2017-01-19    0.0
# 2754  2017-01-19    0.0
# 2755  2017-01-19    0.0
# 2756  2017-01-18    0.0
# 2757  2017-01-18    0.0
# 2758  2017-01-18    0.0
# 2759  2017-01-18    0.0
# 2760  2017-01-18    0.0
# 2761  2017-01-18    0.0
# 2762  2017-01-18    0.0
# 2763  2017-01-18    0.0
# 2764  2017-01-17    1.0
# 2765  2017-01-17    1.0
# 2766  2017-01-17    1.0
# 2767  2017-01-17    1.0
# 2768  2017-01-17    1.0
# 2769  2017-01-17    1.0
# 2770  2017-01-17    1.0
# 2771  2017-01-17    1.0
# 2772  2017-01-17    1.0
# 2773  2017-01-17    1.0
# 2774  2017-01-17    1.0
#
# [2775 rows x 4 columns]

# %%
dataframe=dataframe.drop("Unnamed: 0",axis=1)

# %%
""""def labeller (x):
    if x <0:
        return 0
    else:
        return 1"""
# Out:
# '"def labeller (x):\n    if x <0:\n        return 0\n    else:\n        return 1'

# %%
#dataframe['label']=dataframe['label'].apply(labeller)

# %%
#from collections import Counter
#a=Counter(dataframe['label']==1)

# %%
dataframe
# Out:
#                                                    text        Date  label
# 0     urge americans participate takebackday tomorro...  2018-04-27    1.0
# 1     house intelligence committee report released e...  2018-04-27    1.0
# 2     look forward meeting chancellor angela merkel ...  2018-04-27    1.0
# 3     kanye west performed great service black commu...  2018-04-27    1.0
# 4     please forget great help good friend president...  2018-04-27    1.0
# 5     great staff sgt dan nevins incredible wounded ...  2018-04-27    1.0
# 6     korean war end united states great people prou...  2018-04-27    1.0
# 7     furious year missile launches nuclear testing ...  2018-04-27    1.0
# 8     everybody believing going james comey define l...  2018-04-27    1.0
# 9     u put together strong bid w canada mexico worl...  2018-04-26    1.0
# 10                             loved morning great show  2018-04-26    1.0
# 11                                    interviewed enjoy  2018-04-26    1.0
# 12                                                 maga  2018-04-25    1.0
# 13                                     thank kanye cool  2018-04-25    1.0
# 14    looking forward meeting tim cook apple talking...  2018-04-25    1.0
# 15    spectacular job hosting president france wife ...  2018-04-25    1.0
# 16    busy day planned looking forward watching pres...  2018-04-25    1.0
# 17    congratulations republican debbie lesko big wi...  2018-04-25    1.0
# 18    two great republics linked together timeless b...  2018-04-24    1.0
# 19    today melania honored welcome french president...  2018-04-24    1.0
# 20    worked hard tax reductions illegal immigration...  2018-04-24    1.0
# 21    worked hard tax reductions illegal immigration...  2018-04-24    1.0
# 22    president trump calls u france relationship un...  2018-04-24    1.0
# 23    arizona please get today vote congress az stro...  2018-04-24    1.0
# 24    americans stand canada prime minister thoughts...  2018-04-24    1.0
# 25    great meetings discussions friend president fr...  2018-04-24    1.0
# 26    great stat since january number people forced ...  2018-04-23    0.0
# 27    mexico whose laws immigration tough must stop ...  2018-04-23    0.0
# 28    despite democrat inspired laws sanctuary citie...  2018-04-23    0.0
# 29    hard believe obstructionists may vote mike pom...  2018-04-23    0.0
# ...                                                 ...         ...    ...
# 2745  begins today see swearing movement continues w...  2017-01-20    0.0
# 2746  thank wonderful evening washington c inauguration  2017-01-20    0.0
# 2747  thank joining us lincoln memorial tonight spec...  2017-01-20    0.0
# 2748       join pm lincoln memorial family inauguration  2017-01-19    0.0
# 2749       great concert p today lincoln memorial enjoy  2017-01-19    0.0
# 2750                                   way inauguration  2017-01-19    0.0
# 2751  american people doubt together make america great  2017-01-19    0.0
# 2752  getting ready leave washington c journey begin...  2017-01-19    0.0
# 2753  donald trump divided country country divided l...  2017-01-19    0.0
# 2754  thank amazing wounded warriors service honor t...  2017-01-19    0.0
# 2755  great seeing kimberly evenings vp dinner godbl...  2017-01-19    0.0
# 2756  looking forward speedy recovery george barbara...  2017-01-18    0.0
# 2757  writing inaugural address winter white house m...  2017-01-18    0.0
# 2758  great last night c playing diplomats ambassado...  2017-01-18    0.0
# 2759  wonder today show biased badly compared glorio...  2017-01-18    0.0
# 2760  bayer ag pledged add u jobs investments meetin...  2017-01-18    0.0
# 2761  u nothing trump fake news ask top ceo companie...  2017-01-18    0.0
# 2762  totally biased went way say big announcement f...  2017-01-18    0.0
# 2763                                  interviewed enjoy  2017-01-18    0.0
# 2764  thank general motors walmart starting big jobs...  2017-01-17    1.0
# 2765                                 trump media missed  2017-01-17    1.0
# 2766  thought would hypocritical attend bush swearin...  2017-01-17    1.0
# 2767  john lewis said inauguration first one missed ...  2017-01-17    1.0
# 2768  country massive cost reductions negotiated mil...  2017-01-17    1.0
# 2769  jobs bringing back u even taking office new au...  2017-01-17    1.0
# 2770  people phony election polls wrong approval rat...  2017-01-17    1.0
# 2771  people pouring washington record numbers biker...  2017-01-17    1.0
# 2772             trump great woman real character class  2017-01-17    1.0
# 2773  p places special report daughter ivanka consid...  2017-01-17    1.0
# 2774  appreciate use twitter keep us informed mainta...  2017-01-17    1.0
#
# [2775 rows x 3 columns]

# %%
#matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)
#prices = pd.DataFrame({"price":train_data["SalePrice"], "log(price + 1)":np.log1p(train_data["SalePrice"])})
#prices.hist()
#y_train = np.log1p(y_train)

# %%
print(dataframe['text'][1])
# Out:
# house intelligence committee report released evidence trump campaign colluded coordinated conspired russia clinton campaign paid opposition research obtained russia wow total witch hunt must end

# %%
print(dataframe.groupby(by='label').count())
# Out:
#        text  Date
# label
# -1.0   1092  1095
#  0.0    715   715
#  1.0    965   965

# %%
print(dataframe.shape)
# Out:
# (2775, 3)

# %%
from sklearn.utils import shuffle
dataframe_s = shuffle(dataframe)

# %%
train=dataframe_s.iloc[:2401,:]
test=dataframe_s.iloc[2402:2775,:]

# %%
train=train.dropna()
train=train.drop(columns=['Date'])
test=test.dropna()

# %% [markdown]
# from keras.utils.np_utils import to_categorical
# y_train=to_categorical(train['label'])
# num_class=y_train.shape[1]
# print("num_class=",y_train.shape)

# %%
train['label'].dtype
# Out:
# dtype('float64')

# %%
train['label']=(train['label']+1).astype(int)
test['label']=(test['label']+1).astype(int)

# %%
train['label']
# Out:
# 965     2
# 2693    1
# 2687    1
# 457     1
# 1583    1
# 2056    1
# 2569    0
# 1178    0
# 86      1
# 1939    1
# 1495    2
# 1386    0
# 622     2
# 929     2
# 1451    2
# 331     2
# 2401    0
# 2334    2
# 2303    2
# 2503    2
# 483     2
# 1129    0
# 2120    0
# 2473    0
# 120     0
# 1751    0
# 1916    1
# 940     2
# 1407    1
# 1418    1
#        ..
# 295     1
# 2299    2
# 2386    0
# 819     0
# 1076    2
# 1519    2
# 200     0
# 2279    2
# 702     2
# 1155    0
# 1967    1
# 191     0
# 2355    2
# 2328    1
# 774     0
# 777     0
# 1080    2
# 985     2
# 1672    2
# 318     1
# 2551    0
# 949     2
# 1740    0
# 470     2
# 1648    2
# 2486    2
# 1647    0
# 2027    2
# 2474    0
# 535     2
# Name: label, Length: 2398, dtype: int32

# %% [markdown]
# <font color=#0099ff size=10 face="黑体">tokenizer</font>

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=5000)
# Out:
# Using TensorFlow backend.

# %%
tokenizer.fit_on_texts(train['text'])
vocab_size=len(tokenizer.word_index)+1

# %%
x_train=tokenizer.texts_to_matrix(train['text'])
x_test=tokenizer.texts_to_matrix(test['text'])

# %%
#x_train=x_train.reshape(x_train.shape[0],5000,1)
#x_train.shape
# Out:
# (2377, 5000, 1)

# %%
#x_test=x_test.reshape(x_test.shape[0],5000,1)
#x_test.shape
# Out:
# (426, 5000, 1)

# %%
#print(x_train.shape)
# Out:
# (2377, 5000, 1)

# %%
x_train,x_val,y_train,y_val=train_test_split(x_train,train['label'],test_size=0.10,random_state=42)

# %%
y_train.dtypes
# Out:
# dtype('int32')

# %%
print(x_train.shape)
# Out:
# (2158, 5000)

# %% [markdown]
# x_train,x_val,y_train,y_val=train_test_split(x_train,train['label'],test_size=0.10,random_state=42)

# %% [markdown]
# <font color=#0099ff size=10 face="黑体">Word Embedding</font>

# %%
embeddings_index = dict()
f = open(r'C:\Users\sebas\OneDrive\Documents\Glove\glove.twitter.27B.200d.txt', encoding='utf-8')

# %%
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# create a weight matrix for words in training docs
embedding_matrix = np.zeros((vocab_size, 200))
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# Loaded 1193514 word vectors.

# %% [markdown]
# <font color=#0099ff size=10 face="黑体">Neural Network</font>

# %%
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization,Convolution2D, MaxPooling2D
from keras.layers import Dense , Dropout, Lambda, Flatten, Embedding
from keras import Sequential
from keras import regularizers

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
e = Embedding(vocab_size, 200, weights=[embedding_matrix], input_length=5000, trainable=False)
model.add(e)
#model.add(Dense(50,activation='relu'))
#here the standardize is the function we define upwords
model.add(Dense(50,activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(Flatten())
model.add(Dense(3,activation='softmax'))
#only with softmax, it is a linear model

# %%
from keras.optimizers import SGD 
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

# %%
history = model.fit(x_train, # Features
                      y_train, # Target
                      epochs=10, # Number of epochs
                      verbose=1, # No output
                      batch_size=150, # Number of observations per batch
                      validation_data=(x_val, y_val)) # Data for evaluation
# Out:
# Train on 2158 samples, validate on 240 samples
# Epoch 1/10
# 2158/2158 [==============================] - 22s 10ms/step - loss: 1.7958 - acc: 0.4212 - val_loss: 1.6599 - val_acc: 0.4792
# Epoch 2/10
# 2158/2158 [==============================] - 21s 10ms/step - loss: 1.2340 - acc: 0.7743 - val_loss: 1.5829 - val_acc: 0.4583
# Epoch 3/10
# 2158/2158 [==============================] - 20s 9ms/step - loss: 0.7902 - acc: 0.8800 - val_loss: 1.7247 - val_acc: 0.4625
# Epoch 4/10
# 2158/2158 [==============================] - 20s 9ms/step - loss: 0.5303 - acc: 0.9462 - val_loss: 1.8420 - val_acc: 0.4625
# Epoch 5/10
# 2158/2158 [==============================] - 20s 9ms/step - loss: 0.3859 - acc: 0.9727 - val_loss: 1.9449 - val_acc: 0.4625
# Epoch 6/10
# 2158/2158 [==============================] - 20s 9ms/step - loss: 0.2941 - acc: 0.9782 - val_loss: 1.9852 - val_acc: 0.4708
# Epoch 7/10
# 2158/2158 [==============================] - 20s 9ms/step - loss: 0.2313 - acc: 0.9810 - val_loss: 1.9987 - val_acc: 0.4583
# Epoch 8/10
# 2158/2158 [==============================] - 24s 11ms/step - loss: 0.1859 - acc: 0.9842 - val_loss: 2.0109 - val_acc: 0.4708
# Epoch 9/10
# 2158/2158 [==============================] - 21s 10ms/step - loss: 0.1533 - acc: 0.9856 - val_loss: 2.0289 - val_acc: 0.4625
# Epoch 10/10
# 2158/2158 [==============================] - 20s 9ms/step - loss: 0.1290 - acc: 0.9819 - val_loss: 2.0516 - val_acc: 0.4667

# %%
import matplotlib.pyplot as plt

# %%
# Get training and test loss histories
training_loss = history.history['loss']
test_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
# Get training and test loss histories
training_loss = history.history['acc']
test_loss = history.history['val_acc']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
plt.legend(['Training acc', 'Test acc'])
plt.xlabel('Epoch')
plt.ylabel('acc')
plt.show();

# %% [markdown]
# predict_table = pd.DataFrame( columns=['text','new_label'],index=['1'])

# %% [markdown]
# predict_table['text'][0]="white house correspondents dinner"
# print(predict_table)

# %% [markdown]
# today=tokenizer.texts_to_matrix(predict_table['text'])
# print(today.shape)
# today=today.reshape(today.shape[0],5000,1)

# %% [markdown]
# #X=model.predict(today)
# #print(model.predict(today))

# %% [markdown]
# #predict_table['new-label'][0]=np.argmax(X,axis=1)
# #print(predict_table)

# %% [markdown]
# x=model.predict(x_test)

# %% [markdown]
# from pandas.core.frame import DataFrame

# %% [markdown]
# X=DataFrame(x)

# %% [markdown]
# print(X)

# %% [markdown]
# X['max_value']=X.max(axis=1)
# X['max_index']=np.argmax(x,axis=1)

# %% [markdown]
# predict_test_y=np.array(X['max_index'])
# test_y=np.array(test['label'])

# %% [markdown]
# sum(predict_test_y==test_y)

# %% [markdown]
# #X['predict']=predict_test_y
# #X['acc']=test['label']+2

# %% [markdown]
# y=DataFrame(columns=['predict','acc'])

# %% [markdown]
# ##y['predict']=X['predict']
# #y['acc']=test['label']+2

# %% [markdown]
# final_table = pd.DataFrame({'text':test['text'],'actual':test['label'],'predicted':predict_test_y})

# %%
print(final_table)
# Out:
#                                                    text  actual  predicted
# 566   signed bill reauthorize foreign intelligence c...       1          2
# 596   must security dangerous southern border must g...       0          1
# 142                                    total witch hunt       2          1
# 525   somebody please inform jay z policies black un...       2          0
# 1870  stock market hits another high spirit enthusia...       0          0
# 2371                                     jobs jobs jobs       2          0
# 105   syrian raid perfectly carried precision way fa...       0          0
# 1433  great strength patience forced defend allies c...       2          2
# 335                          getting done jobs security       2          1
# 2125                  figure true meaning covfefe enjoy       0          1
# 344   gridiron dinner last night great fun accomplis...       2          1
# 192                   honor host annual easter egg roll       0          1
# 2526  big dinner governors tonight white house much ...       2          0
# 1982  great day america future security safety court...       2          0
# 1615  returned bedminster nj camp david great meetin...       0          0
# 2411  remember failing apologized subscribers right ...       0          0
# 269   continuing monitor heartbreaking bridge collap...       2          0
# 553   thank brad blakeman grading year one presidenc...       0          1
# 744   put phony photo empty arena hours arrived venu...       0          0
# 1000  people angry point justice department fbi must...       1          0
# 765   today u flag flies half staff honor national p...       0          0
# 314   deal north korea much making completed good on...       0          2
# 1541  texas heeling fast thanks great men women work...       2          2
# 2723  great meeting ford ceo mark fields general mot...       1          0
# 914                                      thank asia usa       2          2
# 1160  hearts affected wildfires california god bless...       0          0
# 2448  james clapper others stated evidence potus col...       0          0
# 485   meeting henry kissinger pm discussing north ko...       2          1
# 799   christmas story begins years ago mother father...       0          0
# 1476  crooked hillary clinton blames everybody every...       2          0
# ...                                                 ...     ...        ...
# 703   deepest sympathies heartfelt prayers victims t...       2          0
# 2269  stated president trump successes unmatched rec...       2          2
# 1107  reason flake corker dropped senate race simple...       0          0
# 2632  know putin deals russia haters going crazy yet...       0          0
# 968   making working hard tax cuts middle class comp...       2          2
# 663   fbi andrew mccabe addition wife getting money ...       2          0
# 1467  bernie sanders pushing hard single payer healt...       2          0
# 867   happy thanksgiving country starting really wel...       2          2
# 237   daca abandoned democrats unfair would tied des...       0          2
# 2354  great confidence china properly deal north kor...       2          2
# 216   administration stands solidarity brave citizen...       0          0
# 274   wonderful back missouri push historic tax cuts...       2          2
# 2457  great progress healthcare improvements made re...       0          2
# 1869                                jobs jobs jobs maga       0          1
# 767   national pearl harbor remembrance day day live...       0          1
# 1137  great book place called heaven dr robert jeffr...       0          0
# 2345  recent kansas election congress really big med...       1          0
# 798   disgraceful verdict kate steinle case wonder p...       0          2
# 516   hillary clinton democratic party try hide fact...       2          2
# 1475  deplorables came back haunt hillary expressed ...       2          2
# 393   armed educators trusted people work within sch...       1          0
# 1337  spoke jerry jones dallas cowboys yesterday jer...       0          0
# 1211      fake news going order demean denigrate hatred       1          0
# 2316  next saturday night holding big rally pennsylv...       2          2
# 2427                       happy medalofhonorday heroes       0          1
# 1054                            great job michaelcaputo       2          0
# 1426                                         nice thank       1          0
# 1282  leaving puerto rico c las vegas early tomorrow...       0          2
# 2567  democrats come story lost election badly made ...       0          0
# 1112  entire world laughing taking advantage us peop...       0          0
#
# [373 rows x 3 columns]

# %%
# -*-coding:utf-8-*-
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

#labels表示你不同类别的代号，比如这里的demo中有13个类别
labels = ['0', '1', '2']

#y_true代表真实的label值 y_pred代表预测得到的lavel值
y_true = test['label']
y_pred = predict_test_y

tick_marks = np.array(range(len(labels))) + 0.5


def plot_confusion_matrix(cm, title='Confusion Matrix', cmap=plt.cm.binary):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    xlocations = np.array(range(len(labels)))
    plt.xticks(xlocations, labels, rotation=90)
    plt.yticks(xlocations, labels)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


cm= confusion_matrix(y_true, y_pred)
print(cm)
np.set_printoptions(precision=2)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print (cm_normalized)
plt.figure(figsize=(12, 8), dpi=120)

ind_array = np.arange(len(labels))
x, y = np.meshgrid(ind_array, ind_array)

for x_val, y_val in zip(x.flatten(), y.flatten()):
    c = cm_normalized[y_val][x_val]
    if c > 0.01:
        plt.text(x_val, y_val, "%0.2f" % (c,), color='red', fontsize=5, va='center', ha='center')
# offset the tick
plt.gca().set_xticks(tick_marks, minor=True)
plt.gca().set_yticks(tick_marks, minor=True)
plt.gca().xaxis.set_ticks_position('none')
plt.gca().yaxis.set_ticks_position('none')
plt.grid(True, which='minor', linestyle='-')
plt.gcf().subplots_adjust(bottom=0.15)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')
# show confusion matrix
plt.show()
# Out:
# [[77 27 42]
#  [37 35 22]
#  [41 32 60]]
# [[0.53 0.18 0.29]
#  [0.39 0.37 0.23]
#  [0.31 0.24 0.45]]

# %% [markdown]
# history = model.fit(x_train, # Features
#                       train['label'], # Target
#                       epochs=20, # Number of epochs
#                       verbose=1, # No output
#                       batch_size=100, # Number of observations per batch
#                       validation_data=(test_features, test_target)) # Data for evaluation

# %% [markdown]
# model=Sequential()
# model.add(Dense(50,input_shape=(5000, 1)))
# #here the standardize is the function we define upwords
# model.add(Dense(50,activation='relu'))
# model.add(Flatten())
# model.add(Dense(5,activation='softmax'))
# #only with softmax, it is a linear model

# %% [markdown]
# !pip install pydot

# %% [markdown]
# class LossHistory(keras.callbacks.Callback):
#     def on_train_begin(self, logs={}):
#         self.losses = {'batch':[], 'epoch':[]}
#         self.accuracy = {'batch':[], 'epoch':[]}
#         self.val_loss = {'batch':[], 'epoch':[]}
#         self.val_acc = {'batch':[], 'epoch':[]}
#
#     def on_batch_end(self, batch, logs={}):
#         self.losses['batch'].append(logs.get('loss'))
#         self.accuracy['batch'].append(logs.get('acc'))
#         self.val_loss['batch'].append(logs.get('val_loss'))
#         self.val_acc['batch'].append(logs.get('val_acc'))
#
#     def on_epoch_end(self, batch, logs={}):
#         self.losses['epoch'].append(logs.get('loss'))
#         self.accuracy['epoch'].append(logs.get('acc'))
#         self.val_loss['epoch'].append(logs.get('val_loss'))
#         self.val_acc['epoch'].append(logs.get('val_acc'))
#
#     def loss_plot(self, loss_type):
#         iters = range(len(self.losses[loss_type]))
#         plt.figure()
#         # acc
#         plt.plot(iters, self.accuracy[loss_type], 'r', label='train acc')
#         # loss
#         plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
#         if loss_type == 'epoch':
#             # val_acc
#             plt.plot(iters, self.val_acc[loss_type], 'b', label='val acc')
#             # val_loss
#             plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
#         plt.grid(True)
#         plt.xlabel(loss_type)
#         plt.ylabel('acc-loss')
#         plt.legend(loc="upper right")
#         plt.show()

# %% [markdown]
# batch_size = 128
# nb_classes = 5
# nb_epoch = 20

# %% [markdown]
# history = LossHistory()
# model.fit(X_train, Y_train,
#             batch_size=batch_size, nb_epoch=nb_epoch,
#             verbose=1,
#             validation_data=(X_test, Y_test),
#             callbacks=[history])

# %% [markdown]
# history.loss_plot('epoch')

# %%
tweets_2018=pd.read_csv('2018 Tweets.csv', header=None, names=['x','text'])

# %%
tweets_2018.head()
# Out:
#     x                                               text
# 0   0  despite many positive events victories media r...
# 1   9  walker stapleton running highly respected repu...
# 2  11                 thank iowa nebraska vote vote vote
# 3  12                                                NaN
# 4  13            beautiful evening iowa god bless u maga

# %%
tweets_2018.drop('x', axis=1,inplace=True)

# %%
tweets_2018.dropna(inplace=True)

# %%
tweets_2018
# Out:
#                                                  text
# 0   despite many positive events victories media r...
# 1   walker stapleton running highly respected repu...
# 2                  thank iowa nebraska vote vote vote
# 4             beautiful evening iowa god bless u maga
# 5   relentless securing funding fix algae problem ...
# 6   president donald j trump approves florida emer...
# 7                                       register vote
# 8   florida imperative heed directions state local...
# 9   looks cat even intense florence good news folk...
# 10  hurricane way florida pan handle major element...
# 11  big announcement friend ambassador nikki haley...
# 12       going iowa tonight rally farmers happy usmca
# 13  great evening last night white house honoring ...
# 14  paid c protesters ready really protest gotten ...
# 17  great see launch cutting edge statewide school...
# 18  every day police officers race darkened allies...
# 19  thank salute honor promise always back forever...
# 20  america police officers earned everlasting gra...
# 21  great honor address international association ...
# 22  departing washington c international associati...
# 23  christopher columbus spirit determination adve...
# 24  good meeting chairman kim today pyongyang prog...
# 25  hand matches arsonist give power angry left wi...
# 26  beautiful evening topeka kansas vote vote vote...
# 27                                  thank kansas love
# 28  crowd front u supreme court tiny looks like pe...
# 29  applaud congratulate u senate confirming great...
# 30  asked steve daines great republican senator mo...
# 31  women kavanaugh many others support good man g...
# 32  women kavanaugh many others support good man g...
# ..                                                ...
# 50  see time go rallies order help great republica...
# 51  mexico canada united states great partnership ...
# 52  blowout numbers new jobs separately services m...
# 53  thank congressman tom reed new york wonderful ...
# 54        thank governor phil bryant great honor maga
# 56  stock market reached time high administration ...
# 57  failing new york times something never seen do...
# 58  congressman texas true fighter patriot highly ...
# 59    thank mississippi together making america great
# 60  today administration provided historic levels ...
# 61  national wage growth highest nearly months acc...
# 62                                   god bless u maga
# 63                             thank mississippi love
# 64            really incredible time nation respected
# 65  usmca wins praise victory american industries ...
# 66                       proud great first lady loves
# 67  yesterday great honor present medal honor rona...
# 68                 reason vote democrat tired winning
# 69  great reviews new usmca thank mexico canada wo...
# 70  happy th birthday tristan special member trump...
# 71                                wow thank tennessee
# 72                               thank tennessee love
# 74  news conference usmca morning rose garden whit...
# 75                      congratulations mexico canada
# 76  deficiencies mistakes nafta greatly opens mark...
# 77  deficiencies mistakes nafta greatly opens mark...
# 78  late last night deadline reached wonderful new...
# 79  wow starting hear democrats thinking obstruct ...
# 80  african american unemployment lowest number hi...
# 81  like many watch saturday night live even thoug...
#
# [77 rows x 1 columns]

# %%
x_new=tokenizer.texts_to_matrix(tweets_2018['text'])

# %%
prediction = model.predict(x_new)
print(prediction)
# Out:
# [[9.83e-01 9.73e-06 1.67e-02]
#  [9.98e-01 2.05e-04 1.34e-03]
#  [4.94e-02 2.12e-01 7.38e-01]
#  [1.85e-01 8.08e-01 7.05e-03]
#  [3.98e-02 5.01e-02 9.10e-01]
#  [1.88e-01 6.62e-01 1.50e-01]
#  [5.56e-01 5.11e-02 3.93e-01]
#  [3.33e-02 3.28e-03 9.63e-01]
#  [9.10e-01 8.67e-02 3.50e-03]
#  [2.05e-01 7.84e-01 1.10e-02]
#  [4.69e-03 6.30e-01 3.65e-01]
#  [2.21e-02 6.52e-01 3.25e-01]
#  [7.01e-01 2.96e-01 3.31e-03]
